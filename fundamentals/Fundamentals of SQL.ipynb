# %%
import pandas as pd
import sqlite3 as sql

# %%
database = "jobs.db"
conn = sql.connect(database)

# %%
conn

# %%
pd.read_sql_query("select * from sqlite_master", conn)
# Out:
#     type                   name      tbl_name  rootpage  \
# 0  table           recent_grads  recent_grads         2
# 1  index  ix_recent_grads_index  recent_grads         3
#
#                                                  sql
# 0  CREATE TABLE "recent_grads" (\n"index" INTEGER...
# 1  CREATE INDEX "ix_recent_grads_index"ON "recent...

# %%
q = """select * from recent_grads"""

pd.read_sql_query(q, conn)
# Out:
#      index  Rank  Major_code                                      Major  \
# 0        0     1        2419                      PETROLEUM ENGINEERING
# 1        1     2        2416             MINING AND MINERAL ENGINEERING
# 2        2     3        2415                  METALLURGICAL ENGINEERING
# 3        3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4        4     5        2405                       CHEMICAL ENGINEERING
# ..     ...   ...         ...                                        ...
# 168    168   169        3609                                    ZOOLOGY
# 169    169   170        5201                     EDUCATIONAL PSYCHOLOGY
# 170    170   171        5202                        CLINICAL PSYCHOLOGY
# 171    171   172        5203                      COUNSELING PSYCHOLOGY
# 172    172   173        3501                            LIBRARY SCIENCE
#
#                Major_category  Total  Sample_size    Men  Women  ShareWomen  \
# ...

# %%
q = """select * from recent_grads limit 10"""

pd.read_sql_query(q, conn)
# Out:
#    index  Rank  Major_code                                      Major  \
# 0      0     1        2419                      PETROLEUM ENGINEERING
# 1      1     2        2416             MINING AND MINERAL ENGINEERING
# 2      2     3        2415                  METALLURGICAL ENGINEERING
# 3      3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      4     5        2405                       CHEMICAL ENGINEERING
# 5      5     6        2418                        NUCLEAR ENGINEERING
# 6      6     7        6202                          ACTUARIAL SCIENCE
# 7      7     8        5001                 ASTRONOMY AND ASTROPHYSICS
# 8      8     9        2414                     MECHANICAL ENGINEERING
# 9      9    10        2408                     ELECTRICAL ENGINEERING
#
#       Major_category  Total  Sample_size    Men  Women  ShareWomen  ...  \
# 0        Engineering   2339           36   2057    282    0.120564  ...
# ...

# %%
q = """select ShareWomen from recent_grads limit 10"""

pd.read_sql_query(q, conn)
# Out:
#    ShareWomen
# 0    0.120564
# 1    0.101852
# 2    0.153037
# 3    0.107313
# 4    0.341631
# 5    0.144967
# 6    0.535714
# 7    0.441356
# 8    0.139793
# 9    0.437847

# %%
q = """select ShareWomen, Major from recent_grads limit 10"""

pd.read_sql_query(q, conn)
# Out:
#    ShareWomen                                      Major
# 0    0.120564                      PETROLEUM ENGINEERING
# 1    0.101852             MINING AND MINERAL ENGINEERING
# 2    0.153037                  METALLURGICAL ENGINEERING
# 3    0.107313  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4    0.341631                       CHEMICAL ENGINEERING
# 5    0.144967                        NUCLEAR ENGINEERING
# 6    0.535714                          ACTUARIAL SCIENCE
# 7    0.441356                 ASTRONOMY AND ASTROPHYSICS
# 8    0.139793                     MECHANICAL ENGINEERING
# 9    0.437847                     ELECTRICAL ENGINEERING

# %%
q = """select ShareWomen, Major from recent_grads
        where ShareWomen > 0.5
        limit 10"""

pd.read_sql_query(q, conn)
# Out:
#    ShareWomen                               Major
# 0    0.535714                   ACTUARIAL SCIENCE
# 1    0.578766                    COMPUTER SCIENCE
# 2    0.558548           ENVIRONMENTAL ENGINEERING
# 3    0.896019                             NURSING
# 4    0.750473  INDUSTRIAL PRODUCTION TECHNOLOGIES
# 5    0.707719    COMPUTER AND INFORMATION SYSTEMS
# 6    0.526476                INFORMATION SCIENCES
# 7    0.753927                 APPLIED MATHEMATICS
# 8    0.524153                        PHARMACOLOGY
# 9    0.688999                        OCEANOGRAPHY

# %%
q = """select ShareWomen, Major from recent_grads
        where ShareWomen > 0.5
        limit 10"""

pd.read_sql_query(q, conn)
# Out:
#    ShareWomen                               Major
# 0    0.535714                   ACTUARIAL SCIENCE
# 1    0.578766                    COMPUTER SCIENCE
# 2    0.558548           ENVIRONMENTAL ENGINEERING
# 3    0.896019                             NURSING
# 4    0.750473  INDUSTRIAL PRODUCTION TECHNOLOGIES
# 5    0.707719    COMPUTER AND INFORMATION SYSTEMS
# 6    0.526476                INFORMATION SCIENCES
# 7    0.753927                 APPLIED MATHEMATICS
# 8    0.524153                        PHARMACOLOGY
# 9    0.688999                        OCEANOGRAPHY

# %%
q = """select ShareWomen, Major from recent_grads
        where ShareWomen > 0.5
       """

pd.read_sql_query(q, conn)
# Out:
#     ShareWomen                               Major
# 0     0.535714                   ACTUARIAL SCIENCE
# 1     0.578766                    COMPUTER SCIENCE
# 2     0.558548           ENVIRONMENTAL ENGINEERING
# 3     0.896019                             NURSING
# 4     0.750473  INDUSTRIAL PRODUCTION TECHNOLOGIES
# ..         ...                                 ...
# 92    0.637293                             ZOOLOGY
# 93    0.817099              EDUCATIONAL PSYCHOLOGY
# 94    0.799859                 CLINICAL PSYCHOLOGY
# 95    0.798746               COUNSELING PSYCHOLOGY
# 96    0.877960                     LIBRARY SCIENCE
#
# [97 rows x 2 columns]

# %%
q = """select ShareWomen, Major from recent_grads
        where ShareWomen > 0.5 and ShareWomen < 0.8
       """

pd.read_sql_query(q, conn)
# Out:
#     ShareWomen                               Major
# 0     0.535714                   ACTUARIAL SCIENCE
# 1     0.578766                    COMPUTER SCIENCE
# 2     0.558548           ENVIRONMENTAL ENGINEERING
# 3     0.750473  INDUSTRIAL PRODUCTION TECHNOLOGIES
# 4     0.707719    COMPUTER AND INFORMATION SYSTEMS
# ..         ...                                 ...
# 74    0.629505              DRAMA AND THEATER ARTS
# 75    0.666119            COMPOSITION AND RHETORIC
# 76    0.637293                             ZOOLOGY
# 77    0.799859                 CLINICAL PSYCHOLOGY
# 78    0.798746               COUNSELING PSYCHOLOGY
#
# [79 rows x 2 columns]

# %%
q = """select ShareWomen, Major from recent_grads
        where ShareWomen > 0.5 or 
        (ShareWomen <= 0.5 and Major_category == "Engineering")
       """

pd.read_sql_query(q, conn)
# Out:
#      ShareWomen                                      Major
# 0      0.120564                      PETROLEUM ENGINEERING
# 1      0.101852             MINING AND MINERAL ENGINEERING
# 2      0.153037                  METALLURGICAL ENGINEERING
# 3      0.107313  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      0.341631                       CHEMICAL ENGINEERING
# ..          ...                                        ...
# 119    0.637293                                    ZOOLOGY
# 120    0.817099                     EDUCATIONAL PSYCHOLOGY
# 121    0.799859                        CLINICAL PSYCHOLOGY
# 122    0.798746                      COUNSELING PSYCHOLOGY
# 123    0.877960                            LIBRARY SCIENCE
#
# [124 rows x 2 columns]

# %%
q = """select ShareWomen, Major from recent_grads
        where ShareWomen > 0.5 or 
        (ShareWomen <= 0.5 and Major_category == "Engineering")
        order by ShareWomen ASC
       """

pd.read_sql_query(q, conn)
# Out:
#      ShareWomen                                      Major
# 0      0.000000     MISCELLANEOUS ENGINEERING TECHNOLOGIES
# 1      0.090713                   ENGINEERING TECHNOLOGIES
# 2      0.101852             MINING AND MINERAL ENGINEERING
# 3      0.107313  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      0.119559                     BIOMEDICAL ENGINEERING
# ..          ...                                        ...
# 119    0.910933                            ANIMAL SCIENCES
# 120    0.923745                       ELEMENTARY EDUCATION
# 121    0.927807           MATHEMATICS AND COMPUTER SCIENCE
# 122    0.967998                  EARLY CHILDHOOD EDUCATION
# 123    0.968954                ANTHROPOLOGY AND ARCHEOLOGY
#
# [124 rows x 2 columns]

# %%
q = """select ShareWomen, Major from recent_grads
        where ShareWomen > 0.5 or 
        (ShareWomen <= 0.5 and Major_category == "Engineering")
        order by ShareWomen DESC
       """

pd.read_sql_query(q, conn)
# Out:
#      ShareWomen                                      Major
# 0      0.968954                ANTHROPOLOGY AND ARCHEOLOGY
# 1      0.967998                  EARLY CHILDHOOD EDUCATION
# 2      0.927807           MATHEMATICS AND COMPUTER SCIENCE
# 3      0.923745                       ELEMENTARY EDUCATION
# 4      0.910933                            ANIMAL SCIENCES
# ..          ...                                        ...
# 119    0.119559                     BIOMEDICAL ENGINEERING
# 120    0.107313  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 121    0.101852             MINING AND MINERAL ENGINEERING
# 122    0.090713                   ENGINEERING TECHNOLOGIES
# 123    0.000000     MISCELLANEOUS ENGINEERING TECHNOLOGIES
#
# [124 rows x 2 columns]

# %%
q = """select * from recent_grads
        where ShareWomen > 0.3 and Major_category == "Engineering"
       """

pd.read_sql_query(q, conn)
# Out:
#     index  Rank  Major_code                                        Major  \
# 0       4     5        2405                         CHEMICAL ENGINEERING
# 1       9    10        2408                       ELECTRICAL ENGINEERING
# 2      13    14        5008                            MATERIALS SCIENCE
# 3      15    16        2402                       BIOLOGICAL ENGINEERING
# 4      16    17        2412     INDUSTRIAL AND MANUFACTURING ENGINEERING
# 5      18    19        2403                    ARCHITECTURAL ENGINEERING
# 6      22    23        2502            ELECTRICAL ENGINEERING TECHNOLOGY
# 7      30    31        2410                    ENVIRONMENTAL ENGINEERING
# 8      33    34        2411       GEOLOGICAL AND GEOPHYSICAL ENGINEERING
# 9      38    39        2503           INDUSTRIAL PRODUCTION TECHNOLOGIES
# 10     58    59        1401                                 ARCHITECTURE
# 11     66    67        2504  MECHANICAL ENGINEERING RELATED TECHNOLOGIES
#
# ...

# %%
q = """select count(ShareWomen) from recent_grads
        where ShareWomen > 0.3 and Major_category == "Engineering"
        limit 5
       """

pd.read_sql_query(q, conn)
# Out:
#    count(ShareWomen)
# 0                 12

# %%
q = """select ShareWomen from recent_grads
        where ShareWomen > 0.3 and Major_category == "Engineering"
        limit 5
       """

pd.read_sql_query(q, conn)
# Out:
#    ShareWomen
# 0    0.341631
# 1    0.437847
# 2    0.310820
# 3    0.320784
# 4    0.343473

# %%
q = """select count(ShareWomen) as No_of_Engineering_Field
        from recent_grads
        where ShareWomen > 0.3 and Major_category == "Engineering"
        limit 5
       """

pd.read_sql_query(q, conn)
# Out:
#    No_of_Engineering_Field
# 0                       12

# %%
q = """select count(ShareWomen) No_of_Engineering_Field
        from recent_grads
        where ShareWomen > 0.3 and Major_category == "Engineering"
        limit 5
       """

pd.read_sql_query(q, conn)
# Out:
#    No_of_Engineering_Field
# 0                       12

# %%
q = """select count(ShareWomen) "No of Engineering Field"
        from recent_grads
        where ShareWomen > 0.3 and Major_category == "Engineering"
        limit 5
       """

pd.read_sql_query(q, conn)
# Out:
#    No of Engineering Field
# 0                       12

# %%
q = """select distinct(Major_category) from recent_grads"""

pd.read_sql_query(q, conn)
# Out:
#                          Major_category
# 0                           Engineering
# 1                              Business
# 2                     Physical Sciences
# 3                   Law & Public Policy
# 4               Computers & Mathematics
# 5       Agriculture & Natural Resources
# 6   Industrial Arts & Consumer Services
# 7                                  Arts
# 8                                Health
# 9                        Social Science
# 10               Biology & Life Science
# 11                            Education
# 12            Humanities & Liberal Arts
# 13             Psychology & Social Work
# 14          Communications & Journalism
# 15                    Interdisciplinary

# %%
q = """select distinct(Major_category), avg(ShareWomen) 
        from recent_grads"""

pd.read_sql_query(q, conn)
# Out:
#   Major_category  avg(ShareWomen)
# 0    Engineering          0.52255

# %%
q = """select Major_category, avg(ShareWomen) Avg_ShareWomen
        from recent_grads
        group by Major_category"""

pd.read_sql_query(q, conn)
# Out:
#                          Major_category  Avg_ShareWomen
# 0       Agriculture & Natural Resources        0.617938
# 1                                  Arts        0.561851
# 2                Biology & Life Science        0.584518
# 3                              Business        0.405063
# 4           Communications & Journalism        0.643835
# 5               Computers & Mathematics        0.512752
# 6                             Education        0.674986
# 7                           Engineering        0.257158
# 8                                Health        0.616857
# 9             Humanities & Liberal Arts        0.676193
# 10  Industrial Arts & Consumer Services        0.449351
# 11                    Interdisciplinary        0.495397
# 12                  Law & Public Policy        0.335990
# 13                    Physical Sciences        0.508749
# 14             Psychology & Social Work        0.777763
# 15                       Social Science        0.539067

# %%
q = """select Major,cast(Women as float), Total from recent_grads"""

pd.read_sql_query(q, conn)
# Out:
#                                          Major  cast(Women as float)  Total
# 0                        PETROLEUM ENGINEERING                 282.0   2339
# 1               MINING AND MINERAL ENGINEERING                  77.0    756
# 2                    METALLURGICAL ENGINEERING                 131.0    856
# 3    NAVAL ARCHITECTURE AND MARINE ENGINEERING                 135.0   1258
# 4                         CHEMICAL ENGINEERING               11021.0  32260
# ..                                         ...                   ...    ...
# 168                                    ZOOLOGY                5359.0   8409
# 169                     EDUCATIONAL PSYCHOLOGY                2332.0   2854
# 170                        CLINICAL PSYCHOLOGY                2270.0   2838
# 171                      COUNSELING PSYCHOLOGY                3695.0   4626
# 172                            LIBRARY SCIENCE                 964.0   1098
#
# [173 rows x 3 columns]

# %%
q = """select Major, (Women/Total) * 100 from recent_grads"""

pd.read_sql_query(q, conn)
# Out:
#                                          Major  (Women/Total) * 100
# 0                        PETROLEUM ENGINEERING                    0
# 1               MINING AND MINERAL ENGINEERING                    0
# 2                    METALLURGICAL ENGINEERING                    0
# 3    NAVAL ARCHITECTURE AND MARINE ENGINEERING                    0
# 4                         CHEMICAL ENGINEERING                    0
# ..                                         ...                  ...
# 168                                    ZOOLOGY                    0
# 169                     EDUCATIONAL PSYCHOLOGY                    0
# 170                        CLINICAL PSYCHOLOGY                    0
# 171                      COUNSELING PSYCHOLOGY                    0
# 172                            LIBRARY SCIENCE                    0
#
# [173 rows x 2 columns]

# %%
int(282/2339) * 100
# Out:
# 0

# %%
0 * 100

# %%
q = """select Major, (Women/cast(Total as float)) * 100 from recent_grads"""

pd.read_sql_query(q, conn)
# Out:
#                                          Major  \
# 0                        PETROLEUM ENGINEERING
# 1               MINING AND MINERAL ENGINEERING
# 2                    METALLURGICAL ENGINEERING
# 3    NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4                         CHEMICAL ENGINEERING
# ..                                         ...
# 168                                    ZOOLOGY
# 169                     EDUCATIONAL PSYCHOLOGY
# 170                        CLINICAL PSYCHOLOGY
# 171                      COUNSELING PSYCHOLOGY
# 172                            LIBRARY SCIENCE
#
#      (Women/cast(Total as float)) * 100
# 0                             12.056434
# 1                             10.185185
# 2                             15.303738
# 3                             10.731320
# 4                             34.163050
# ..                                  ...
# 168                           63.729338
# 169                           81.709881
# ...

# %%
q = """select Major, 
    round((Women/cast(Total as float)) * 100, 2) Percentage_Women_Grdas 
    from recent_grads"""

pd.read_sql_query(q, conn)
# Out:
#                                          Major  Percentage_Women_Grdas
# 0                        PETROLEUM ENGINEERING                   12.06
# 1               MINING AND MINERAL ENGINEERING                   10.19
# 2                    METALLURGICAL ENGINEERING                   15.30
# 3    NAVAL ARCHITECTURE AND MARINE ENGINEERING                   10.73
# 4                         CHEMICAL ENGINEERING                   34.16
# ..                                         ...                     ...
# 168                                    ZOOLOGY                   63.73
# 169                     EDUCATIONAL PSYCHOLOGY                   81.71
# 170                        CLINICAL PSYCHOLOGY                   79.99
# 171                      COUNSELING PSYCHOLOGY                   79.87
# 172                            LIBRARY SCIENCE                   87.80
#
# [173 rows x 2 columns]

# %%
q = """select Major, 
    round((Women/cast(Total as float)) * 100, 2) Percentage_Women_Grdas 
    from recent_grads
    where Percentage_Women_Grdas > 100 """

pd.read_sql_query(q, conn)
# Out:
#                                                 Major  Percentage_Women_Grdas
# 0                               AEROSPACE ENGINEERING                  106.36
# 1                                        FOOD SCIENCE                  655.26
# 2         MATERIALS ENGINEERING AND MATERIALS SCIENCE                  113.06
# 3              GEOLOGICAL AND GEOPHYSICAL ENGINEERING                  529.31
# 4   NUCLEAR, INDUSTRIAL RADIOLOGY, AND BIOLOGICAL ...                  270.65
# 5                                             PHYSICS                  100.93
# 6                     STATISTICS AND DECISION SCIENCE                  144.97
# 7                                 APPLIED MATHEMATICS                  242.92
# 8                                        PHARMACOLOGY                 5908.85
# 9                    MATHEMATICS AND COMPUTER SCIENCE                 1694.58
# 10                          SCHOOL STUDENT COUNSELING                  264.55
# ...

# %%
q = """select Major, 
    round((Women/cast(Total as float)) * 100, 2) Percentage_Women_Grdas 
    from recent_grads
    where Percentage_Women_Grdas > 100 """

pd.read_sql_query(q, conn)
# Out:
#                                                 Major  Percentage_Women_Grdas
# 0                               AEROSPACE ENGINEERING                  106.36
# 1                                        FOOD SCIENCE                  655.26
# 2         MATERIALS ENGINEERING AND MATERIALS SCIENCE                  113.06
# 3              GEOLOGICAL AND GEOPHYSICAL ENGINEERING                  529.31
# 4   NUCLEAR, INDUSTRIAL RADIOLOGY, AND BIOLOGICAL ...                  270.65
# 5                                             PHYSICS                  100.93
# 6                     STATISTICS AND DECISION SCIENCE                  144.97
# 7                                 APPLIED MATHEMATICS                  242.92
# 8                                        PHARMACOLOGY                 5908.85
# 9                    MATHEMATICS AND COMPUTER SCIENCE                 1694.58
# 10                          SCHOOL STUDENT COUNSELING                  264.55
# ...

# %%
q = """select Major, 
    men, women, total
    from recent_grads
    where Major == "FOOD SCIENCE" """

pd.read_sql_query(q, conn)
# Out:
#           Major    Men  Women  Total
# 0  FOOD SCIENCE  99743  28576   4361

# %%
99743 + 28576

# %%
q = """select Major, 
     (cast(women as float)/(men + women))* 100 Percentage_Women_Grads  
    from recent_grads
    where Percentage_Women_Grads > 50
    """

pd.read_sql_query(q, conn)
# Out:
#                                  Major  Percentage_Women_Grads
# 0                    ACTUARIAL SCIENCE               53.571429
# 1                     COMPUTER SCIENCE               57.876634
# 2            ENVIRONMENTAL ENGINEERING               55.854801
# 3                              NURSING               89.601899
# 4   INDUSTRIAL PRODUCTION TECHNOLOGIES               75.047259
# ..                                 ...                     ...
# 92                             ZOOLOGY               63.729338
# 93              EDUCATIONAL PSYCHOLOGY               81.709881
# 94                 CLINICAL PSYCHOLOGY               79.985906
# 95               COUNSELING PSYCHOLOGY               79.874622
# 96                     LIBRARY SCIENCE               87.795993
#
# [97 rows x 2 columns]

# %%
q = """select Major, Major_Category, ShareWomen from recent_grads
    where Women > Men
    """

pd.read_sql_query(q, conn)
# Out:
#                                  Major            Major_category  ShareWomen
# 0                    ACTUARIAL SCIENCE                  Business    0.535714
# 1                     COMPUTER SCIENCE   Computers & Mathematics    0.578766
# 2            ENVIRONMENTAL ENGINEERING               Engineering    0.558548
# 3                              NURSING                    Health    0.896019
# 4   INDUSTRIAL PRODUCTION TECHNOLOGIES               Engineering    0.750473
# ..                                 ...                       ...         ...
# 92                             ZOOLOGY    Biology & Life Science    0.637293
# 93              EDUCATIONAL PSYCHOLOGY  Psychology & Social Work    0.817099
# 94                 CLINICAL PSYCHOLOGY  Psychology & Social Work    0.799859
# 95               COUNSELING PSYCHOLOGY  Psychology & Social Work    0.798746
# 96                     LIBRARY SCIENCE                 Education    0.877960
#
# [97 rows x 3 columns]

# %%
q = """select Major, Major_Category, ShareWomen from recent_grads
    where Women > Men and 
    Major_category IN ("Engineering","Physical Sciences")
    """

pd.read_sql_query(q, conn)
# Out:
#                                    Major     Major_category  ShareWomen
# 0              ENVIRONMENTAL ENGINEERING        Engineering    0.558548
# 1     INDUSTRIAL PRODUCTION TECHNOLOGIES        Engineering    0.750473
# 2                           OCEANOGRAPHY  Physical Sciences    0.688999
# 3                              CHEMISTRY  Physical Sciences    0.505141
# 4                            GEOSCIENCES  Physical Sciences    0.881294
# 5  MULTI-DISCIPLINARY OR GENERAL SCIENCE  Physical Sciences    0.669999

# %%
q = """select Major, Major_Category, ShareWomen from recent_grads
    where  
    Major_category IN ("Engineering","Physical Sciences")
    and
    ShareWomen Between 0.5 and 0.8
    """

pd.read_sql_query(q, conn)
# Out:
#                                    Major     Major_category  ShareWomen
# 0              ENVIRONMENTAL ENGINEERING        Engineering    0.558548
# 1     INDUSTRIAL PRODUCTION TECHNOLOGIES        Engineering    0.750473
# 2                           OCEANOGRAPHY  Physical Sciences    0.688999
# 3                              CHEMISTRY  Physical Sciences    0.505141
# 4  MULTI-DISCIPLINARY OR GENERAL SCIENCE  Physical Sciences    0.669999

# %%
q = """select Major_Category, avg(ShareWomen) Avg_ShareWomen
    from recent_grads
    group by 1
    Having Avg_ShareWomen > 0.5
    """

pd.read_sql_query(q, conn)
# Out:
#                      Major_category  Avg_ShareWomen
# 0   Agriculture & Natural Resources        0.617938
# 1                              Arts        0.561851
# 2            Biology & Life Science        0.584518
# 3       Communications & Journalism        0.643835
# 4           Computers & Mathematics        0.512752
# 5                         Education        0.674986
# 6                            Health        0.616857
# 7         Humanities & Liberal Arts        0.676193
# 8                 Physical Sciences        0.508749
# 9          Psychology & Social Work        0.777763
# 10                   Social Science        0.539067

# %%
q = """select Major_Category, avg(ShareWomen) Avg_ShareWomen
    from recent_grads
    where ShareWomen > 0.3
    group by 1
    Having Avg_ShareWomen > 0.5
    """

pd.read_sql_query(q, conn)
# Out:
#                      Major_category  Avg_ShareWomen
# 0   Agriculture & Natural Resources        0.661854
# 1                              Arts        0.561851
# 2            Biology & Life Science        0.623524
# 3                          Business        0.500167
# 4       Communications & Journalism        0.643835
# 5           Computers & Mathematics        0.666308
# 6                         Education        0.674986
# 7                            Health        0.656663
# 8         Humanities & Liberal Arts        0.676193
# 9               Law & Public Policy        0.533731
# 10                Physical Sciences        0.551394
# 11         Psychology & Social Work        0.777763
# 12                   Social Science        0.539067

# %%
q = """select avg(ShareWomen) from recent_grads"""

pd.read_sql_query(q, conn)
# Out:
#    avg(ShareWomen)
# 0          0.52255

# %%
q = """select Major_category,major, ShareWomen 
        from recent_grads
        where ShareWomen > 0.52255"""

pd.read_sql_query(q, conn)
# Out:
#               Major_category                               Major  ShareWomen
# 0                   Business                   ACTUARIAL SCIENCE    0.535714
# 1    Computers & Mathematics                    COMPUTER SCIENCE    0.578766
# 2                Engineering           ENVIRONMENTAL ENGINEERING    0.558548
# 3                     Health                             NURSING    0.896019
# 4                Engineering  INDUSTRIAL PRODUCTION TECHNOLOGIES    0.750473
# ..                       ...                                 ...         ...
# 86    Biology & Life Science                             ZOOLOGY    0.637293
# 87  Psychology & Social Work              EDUCATIONAL PSYCHOLOGY    0.817099
# 88  Psychology & Social Work                 CLINICAL PSYCHOLOGY    0.799859
# 89  Psychology & Social Work               COUNSELING PSYCHOLOGY    0.798746
# 90                 Education                     LIBRARY SCIENCE    0.877960
#
# [91 rows x 3 columns]

# %%
q = """select Major_category,major, ShareWomen 
        from recent_grads
        where ShareWomen > avg(ShareWomen)"""

pd.read_sql_query(q, conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    2022         try:
# -> 2023             cur.execute(*args, **kwargs)
#    2024             return cur
#
# OperationalError: misuse of aggregate function avg()
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6052\430312876.py in <module>
#       3         where ShareWomen > avg(ShareWomen)"""
#       4
# ----> 5 pd.read_sql_query(q, conn)
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     398     """
#     399     pandas_sql = pandasSQL_builder(con)
# --> 400     return pandas_sql.read_query(
#     401         sql,
# ...

# %%
q = """select avg(ShareWomen) from recent_grads"""

pd.read_sql_query(q, conn)
# Out:
#    avg(ShareWomen)
# 0          0.52255

# %%
q = """select Major_category,major, ShareWomen 
        from recent_grads
        where ShareWomen > (select avg(ShareWomen) from recent_grads)"""

pd.read_sql_query(q, conn)
# Out:
#               Major_category                               Major  ShareWomen
# 0                   Business                   ACTUARIAL SCIENCE    0.535714
# 1    Computers & Mathematics                    COMPUTER SCIENCE    0.578766
# 2                Engineering           ENVIRONMENTAL ENGINEERING    0.558548
# 3                     Health                             NURSING    0.896019
# 4                Engineering  INDUSTRIAL PRODUCTION TECHNOLOGIES    0.750473
# ..                       ...                                 ...         ...
# 86    Biology & Life Science                             ZOOLOGY    0.637293
# 87  Psychology & Social Work              EDUCATIONAL PSYCHOLOGY    0.817099
# 88  Psychology & Social Work                 CLINICAL PSYCHOLOGY    0.799859
# 89  Psychology & Social Work               COUNSELING PSYCHOLOGY    0.798746
# 90                 Education                     LIBRARY SCIENCE    0.877960
#
# [91 rows x 3 columns]

# %%
q = """select count(Major_category)
        from recent_grads
        where ShareWomen > (select avg(ShareWomen) from recent_grads)"""

pd.read_sql_query(q, conn)
# Out:
#    count(Major_category)
# 0                     91

# %%
q = """select count(Major_category) from recent_grads"""

pd.read_sql_query(q, conn)
# Out:
#    count(Major_category)
# 0                    173

# %%
q = """select count(Major_category) No_of_fields_avg_sh, 
        (select count(Major_category) from recent_grads) Total_of_Fields
        from recent_grads
        where ShareWomen > (select avg(ShareWomen) from recent_grads)"""

pd.read_sql_query(q, conn)
# Out:
#    No_of_fields_avg_sh  Total_of_Fields
# 0                   91              173

# %%
q = """select count(Major_category) No_of_fields_avg_sh, 
        (select count(Major_category) from recent_grads) Total_of_Fields
        from recent_grads
        where ShareWomen > (select avg(ShareWomen) from recent_grads)"""

pd.read_sql_query(q, conn)
# Out:
#    No_of_fields_avg_sh  Total_of_Fields
# 0                   91              173

# %%
q = """select Major_category 
        from recent_grads
        order by Men + Women DESC
        limit 3"""

pd.read_sql_query(q, conn)
# Out:
#              Major_category
# 0  Psychology & Social Work
# 1            Social Science
# 2    Biology & Life Science

# %%
q = """select Major, Major_category
        from recent_grads
        where Major_category IN (select Major_category 
                                from recent_grads
                                order by Men + Women DESC
                                limit 3)"""

pd.read_sql_query(q, conn)
# Out:
#                                         Major            Major_category
# 0                                   ECONOMICS            Social Science
# 1                                PHARMACOLOGY    Biology & Life Science
# 2         COGNITIVE SCIENCE AND BIOPSYCHOLOGY    Biology & Life Science
# 3                     INTERNATIONAL RELATIONS            Social Science
# 4                           MOLECULAR BIOLOGY    Biology & Life Science
# 5                                    GENETICS    Biology & Life Science
# 6               MISCELLANEOUS SOCIAL SCIENCES            Social Science
# 7    INDUSTRIAL AND ORGANIZATIONAL PSYCHOLOGY  Psychology & Social Work
# 8            POLITICAL SCIENCE AND GOVERNMENT            Social Science
# 9                                   GEOGRAPHY            Social Science
# 10                               MICROBIOLOGY    Biology & Life Science
# 11                       BIOCHEMICAL SCIENCES    Biology & Life Science
# ...
